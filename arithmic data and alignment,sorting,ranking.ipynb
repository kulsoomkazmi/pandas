# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series([0.5,1,1.5,2,2.5],index=["a", "c", 'd', 'e', 'f'])
s1
# Out:
# a    0.5
# c    1.0
# d    1.5
# e    2.0
# f    2.5
# dtype: float64

# %%
s2 = pd.Series([5,6,7,8],index=['a', 'b', 'e', 'f'])
s2
# Out:
# a    5
# b    6
# e    7
# f    8
# dtype: int64

# %%
s1 + s2
# Out:
# a     5.5
# b     NaN
# c     NaN
# d     NaN
# e     9.0
# f    10.5
# dtype: float64

# %%
s1.radd?

# %%
s1.radd(s2)
# Out:
# a     5.5
# b     NaN
# c     NaN
# d     NaN
# e     9.0
# f    10.5
# dtype: float64

# %%
df1 = pd.DataFrame(np.arange(9).reshape(3,3),columns=list('bde'),index=["ohio", "colardo", "texas"])
df1
# Out:
#          b  d  e
# ohio     0  1  2
# colardo  3  4  5
# texas    6  7  8

# %%
df2 = pd.DataFrame(np.arange(12).reshape(4,3),columns=list('bce'),index=['ohio','colardo','oregon', 'utah'])
df2
# Out:
#          b   c   e
# ohio     0   1   2
# colardo  3   4   5
# oregon   6   7   8
# utah     9  10  11

# %%
df1 + df2
# Out:
#            b   c   d     e
# colardo  6.0 NaN NaN  10.0
# ohio     0.0 NaN NaN   4.0
# oregon   NaN NaN NaN   NaN
# texas    NaN NaN NaN   NaN
# utah     NaN NaN NaN   NaN

# %%
df1.add(df2,fill_value=0)
# Out:
#            b     c    d     e
# colardo  6.0   4.0  4.0  10.0
# ohio     0.0   1.0  1.0   4.0
# oregon   6.0   7.0  NaN   8.0
# texas    6.0   NaN  7.0   8.0
# utah     9.0  10.0  NaN  11.0

# %% [markdown]
# ## sorting

# %% [markdown]
# ###### data.sort_values(
#     by,
#     axis=0,
#     ascending=True,
#     inplace=False,
#     kind='quicksort',
#     na_position='last',
# )

# %%
obj = pd.Series([4,6,3,2,1],index=list('bcdea'))
obj
# Out:
# b    4
# c    6
# d    3
# e    2
# a    1
# dtype: int64

# %%
obj.sort_index()
# Out:
# a    1
# b    4
# c    6
# d    3
# e    2
# dtype: int64

# %%
obj.sort_values()
# Out:
# a    1
# e    2
# d    3
# b    4
# c    6
# dtype: int64

# %%
df = pd.DataFrame({'b':[3,68,1],'a':[99,12,4]},index=[3,2,1])
df
# Out:
#     b   a
# 3   3  99
# 2  68  12
# 1   1   4

# %%
df.sort_index()
# Out:
#     b   a
# 1   1   4
# 2  68  12
# 3   3  99

# %%
df.sort_values(by='a',ascending=False)
# Out:
#     b   a
# 3   3  99
# 2  68  12
# 1   1   4

# %%
df.sort_values(by='b')
# Out:
#     b   a
# 1   1   4
# 3   3  99
# 2  68  12

# %% [markdown]
# # ranking

# %% [markdown]
# ###### data.rank(
#     axis=0,
#     method='average',
#     numeric_only=None,
#     na_option='keep',
#     ascending=True,
#     pct=False,

# %%
ser = pd.Series([7,-5,7,4,2,0,4])
ser
# Out:
# 0    7
# 1   -5
# 2    7
# 3    4
# 4    2
# 5    0
# 6    4
# dtype: int64

# %%
sort =  ser.sort_values()
sort
# Out:
# 1   -5
# 5    0
# 4    2
# 3    4
# 6    4
# 0    7
# 2    7
# dtype: int64

# %%
sort.rank()
# Out:
# 1    1.0
# 5    2.0
# 4    3.0
# 3    4.5
# 6    4.5
# 0    6.5
# 2    6.5
# dtype: float64

# %%
data = pd.read_csv('heart.csv')

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.sort_values('age').head(60)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 60    29    1   1       130   204    0        0      202      0      0.0
# 118   29    1   1       130   204    0        0      202      0      0.0
# 668   29    1   1       130   204    0        0      202      0      0.0
# 64    29    1   1       130   204    0        0      202      0      0.0
# 572   34    1   3       118   182    0        0      174      0      0.0
# 143   34    1   3       118   182    0        0      174      0      0.0
# 779   34    0   1       118   210    0        1      192      0      0.7
# 15    34    0   1       118   210    0        1      192      0      0.7
# 201   34    1   3       118   182    0        0      174      0      0.0
# 12    34    0   1       118   210    0        1      192      0      0.7
# 912   35    1   0       120   198    0        1      130      1      1.6
# 846   35    0   0       138   183    0        1      182      0      1.4
# ...

# %%
data["age"].sort_values().rank(method='min',ascending=True,).head(60) #method[min,'max','average','dense','first']
# Out:
# 60      1.0
# 118     1.0
# 668     1.0
# 64      1.0
# 572     5.0
# 143     5.0
# 779     5.0
# 15      5.0
# 201     5.0
# 12      5.0
# 912    11.0
# 846    11.0
# 841    11.0
# 701    11.0
# 711    11.0
# 666    11.0
# 254    11.0
# 256    11.0
# 281    11.0
# 298    11.0
# 501    11.0
# 483    11.0
# 699    11.0
# 695    11.0
# 384    11.0
# 330    26.0
# 68     26.0
# 84     26.0
# 851    26.0
# 433    26.0
# 332    26.0
# 627    32.0
# 933    32.0
# 919    32.0
# 597    32.0
# 52     32.0
# 258    32.0
# 340    32.0
# 208    32.0
# 465    32.0
# 970    32.0
# 83     32.0
# 242    32.0
# 871    44.0
# 457    44.0
# 975    44.0
# 149    44.0
# 272    44.0
# 478    44.0
# 694    44.0
# 223    44.0
# 173    44.0
# 248    44.0
# 558    44.0
# 657    44.0
# 981    44.0
# 920    44.0
# 145    58.0
# 810    58.0
# 108    58.0
# Name: age, dtype: float64
